# %%
import pandas as pd
import re

# %%
df = pd.read_excel('offers_unlabeled.xlsx')

# %%
df = df.drop(['Unnamed: 0'], axis=1)

# %%
df.head()
# Out:
#                                                 name  \
# 0  Administrateur-ice des Vente Plateforme Logist...
# 1             Responsable Ressources Humaines Siège
# 2  CHEF DE PRODUIT SENIOR PRODUITS FINIS   CHEF D...
# 3         -Responsable Industriel d'Offre Nucléaire
# 4   Responsable projet / Gestionnaire de Configur...
#
#                                                 link       company  \
# 0  https://joinus.saint-gobain.com/fr/fra/spc/p/2...  Saint Gobain
# 1  https://joinus.saint-gobain.com/fr/fra/hr/p/46...  Saint Gobain
# 2  https://jobs.richemont.com/Chloe/job/paris-CHE...         Chloé
# 3  https://www.naval-group.com/fr/talents/offer/P...   Naval Group
# 4  https://www.naval-group.com/fr/talents/offer/P...   Naval Group
#
#                       function  \
# 0                          NaN
# 1                          NaN
# 2                    Marketing
# 3  Commerce, marketing , Offre
# 4                   Programmes
#
# ...

# %%
df['company'].value_counts()
# Out:
# Saint Gobain          364
# Framatome             340
# Fnac Darty            291
# Nexter                200
# MBDA                  182
# Thales                160
# Naval Group           157
# Alstom                125
# LVMH                   99
# Dassault Aviation      81
# Hermes                 66
# Safran                 57
# EDF                    54
# RATP Dev               37
# L'Oreal                35
# Engie                  21
# Sanofi                 18
# Cartier                18
# Van Cleef & Arpels     16
# Motul                  13
# Air France             12
# Lisi Aerospace         12
# Chloé                  11
# Watchfinder             5
# Richemont               3
# Buccellati              3
# Alaïa                   2
# Baume & Mercier         1
# Name: company, dtype: int64
