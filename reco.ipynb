# %%
import pandas as pd

# %%
df = pd.read_json('raw_db.json')

# %%
df
# Out:
#                                                Position  \
# 0                STAGE – Développeur Web Full Stack H/F
# 1     STAGE - Ingénierie Analyse des Paramètres Enre...
# 2                Alternance – Développeur Front-End H/F
# 3     ALTERNANCE – Assistance à Maîtrise d'Ouvrage -...
# 4                                  Juriste HOP! CDD H/F
# ...                                                 ...
# 2033  Ingénieur Maîtrise d'Ouvrage Informatique et C...
# 2034                        Administrateur systèmes H/F
# 2035  Ingénieur Bureau d'Etudes Installations Systèm...
# 2036  Ingénieur Bureau d'Etudes Installations Circui...
# 2037  Ingénieur Support Technique Développement Admi...
#
#                                                    link            Company  \
# 0     /offre-de-emploi/emploi-stage-developpeur-web-...         Air France
# 1     /offre-de-emploi/emploi-stage-ingenierie-analy...         Air France
# ...
