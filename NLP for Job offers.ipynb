# %%
import pandas as pd
import matplotlib.pyplot as plt
import nltk

pd.set_option('display.max_colwidth', None)

# %%
df = pd.read_csv('backup/richemont_db.csv')

# %%
df = df.drop(columns=('Unnamed: 0'))
df
# Out:
#                                                           Position  \
# 0        Stagiaire Coordinateur/rice Productions Editoriales (H/F)
# 1                                       TECHNICIENNE PRODUIT (H/F)
# 2                    Chargé(e) d'Administration du Personnel (CDD)
# 3                              Apprentissage - Contrôle de gestion
# 4    STAGE CHEF DE PROJETS DEVELOPPEMENT NOUVEAUTES PRODUITS (H/F)
# ..                                                             ...
# 112                                    Stage - Contrôle de Gestion
# 113                     Stage Coordinateur Media et Digital Junior
# 114                               RETAIL MERCHANDISER EUROPE (H/F)
# 115                                         Technicien usinage H/F
# 116                                               GEMMOLOGUE (H/F)
#
#                                                                                            link  \
# ...

# %%
text = str(df.iloc[0:1]['desc'])
text = text.replace('\xa0', '').replace('\\n', ' ').replace('[ ]{1,} ', '')
print(text) #Create test sample
# Out:
# 0    Créée en 1983, la Maison Azzedine Alaïa, sous le contrôle artistique de Monsieur Alaïa, s'est forgée une réputation tant dans l'originalité du design que dans le choix et la coupe des matériaux. Chaque pièce issue de l'atelier parisien de Monsieur Alaïa est unique, confectionnée avec passion dans un pur savoir-faire traditionnel. En 2007, La Maison Azzedine Alaïa s’est associée au Groupe Richemont. Aujourd’hui, la Maison Alaïa est présente dans plus d’une centaine de points de distribution à travers le monde et dispose de 7 points de vente en France et à l’international (Paris – 2 boutiques et 2 Corners au Galeries Lafayette, Londres, Dubaï et le Japon).  La Maison Alaïa est à la recherche d’un(e):   Stagiaire Coordinateur/rice Productions Editoriales (H/F) Temps plein – 4 mois Début: asap  Quelles sont vos missions?  Rattaché(e) au pôle Communication et Marketing, vous avez pour mission de contribuer au développement des outils éditoriaux digitaux et la gestion administrative d
# ...

# %%
sentences = nltk.sent_tokenize(text) # Tokenize it to sentence
sentences
# Out:
# ["0    Créée en 1983, la Maison Azzedine Alaïa, sous le contrôle artistique de Monsieur Alaïa, s'est forgée une réputation tant dans l'originalité du design que dans le choix et la coupe des matériaux.",
#  "Chaque pièce issue de l'atelier parisien de Monsieur Alaïa est unique, confectionnée avec passion dans un pur savoir-faire traditionnel.",
#  'En 2007, La Maison Azzedine Alaïa s’est associée au Groupe Richemont.',
#  'Aujourd’hui, la Maison Alaïa est présente dans plus d’une centaine de points de distribution à travers le monde et dispose de 7 points de vente en France et à l’international (Paris – 2 boutiques et 2 Corners au Galeries Lafayette, Londres, Dubaï et le Japon).',
#  'La Maison Alaïa est à la recherche d’un(e):   Stagiaire Coordinateur/rice Productions Editoriales (H/F) Temps plein – 4 mois Début: asap  Quelles sont vos missions?',
# ...

# %%
nltk.word_tokenize(sentences[1])
# Out:
# ['Chaque',
#  'pièce',
#  'issue',
#  'de',
#  "l'atelier",
#  'parisien',
#  'de',
#  'Monsieur',
#  'Alaïa',
#  'est',
#  'unique',
#  ',',
#  'confectionnée',
#  'avec',
#  'passion',
#  'dans',
#  'un',
#  'pur',
#  'savoir-faire',
#  'traditionnel',
#  '.']
